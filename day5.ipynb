# %% [markdown]
# # 🎨 Colormap Usage with Practice & Interactivity
# This version includes:
# - New plot types (Seaborn, Plotly)
# - Diverse colormap applications
# - Interactive widgets to explore colormaps and data
# - Practice exercises (TODO prompts)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from ipywidgets import interact, widgets
from mpl_toolkits.mplot3d import Axes3D

# %%
# Helper: List of some common matplotlib colormaps
cmaps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis', 
         'coolwarm', 'bwr', 'seismic', 'cubehelix', 'rainbow']
cmaps

# %%
def plot_interactive_colormap(cmap='viridis'):
    data = np.random.rand(10, 10)
    plt.figure(figsize=(6,4))
    plt.imshow(data, cmap=cmap)
    plt.title(f"Colormap: {cmap}")
    plt.colorbar()
    plt.show()

interact(plot_interactive_colormap, cmap=cmaps)

# %%
# Plotly Example: Interactive heatmap
data = np.random.rand(10,10)
fig = px.imshow(data, color_continuous_scale='Viridis', title='Plotly Heatmap')
fig.show()

# %%
# Seaborn Example: Heatmap
data = np.random.rand(10,12)
sns.heatmap(data, cmap='coolwarm')
plt.title('Seaborn Heatmap with coolwarm colormap')
plt.show()

# %%
# 3D Surface Plot with colormap
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='plasma')
fig.colorbar(surf)
plt.title('3D Surface Plot with plasma colormap')
plt.show()

# %% [markdown]
# ## ✅ **Practice Prompts**
# 1. 🔧 **Change the colormap** in the Seaborn heatmap to a diverging one like `'seismic'`.
# 2. 🔧 **Replace** the matplotlib imshow with a scatter plot where color represents magnitude.
# 3. 🔧 **Create an interactive Plotly 3D surface plot** with a dropdown to select the colormap.
# 4. 🔧 **Try creating a contour plot** with a colormap of your choice.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Load the Iris dataset
url = 'https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'
iris = pd.read_csv(url)

fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Sequential colormap
sc1 = axs[0, 0].scatter(iris['sepal_length'], iris['sepal_width'], c=iris['petal_length'], cmap='viridis')
plt.colorbar(sc1, ax=axs[0, 0], label='Petal Length (cm)')
axs[0, 0].set_title('Sequential: Sepal Length vs Sepal Width')
axs[0, 0].set_xlabel('Sepal Length (cm)')
axs[0, 0].set_ylabel('Sepal Width (cm)')

# Diverging colormap
petal_diff = iris['petal_length'] - iris['petal_width']
sc2 = axs[0, 1].scatter(iris['petal_length'], iris['petal_width'], c=petal_diff, cmap='coolwarm')
plt.colorbar(sc2, ax=axs[0, 1], label='Petal Length - Petal Width')
axs[0, 1].set_title('Diverging: Petal Length vs Petal Width')
axs[0, 1].set_xlabel('Petal Length (cm)')
axs[0, 1].set_ylabel('Petal Width (cm)')

# Qualitative colormap
species = iris['species'].astype('category').cat.codes
sc3 = axs[1, 0].scatter(iris['sepal_length'], iris['sepal_width'], c=species, cmap='tab10')
plt.colorbar(sc3, ax=axs[1, 0], ticks=[0,1,2], label='Species')
axs[1, 0].set_title('Qualitative: Sepal Length vs Sepal Width by Species')
axs[1, 0].set_xlabel('Sepal Length (cm)')
axs[1, 0].set_ylabel('Sepal Width (cm)')

# Custom colorbar
sc4 = axs[1, 1].scatter(iris['petal_length'], iris['petal_width'], c=iris['sepal_length'], cmap='plasma')
cb = plt.colorbar(sc4, ax=axs[1, 1], orientation='horizontal', pad=0.2, label='Sepal Length (cm)')
axs[1, 1].set_title('Custom Colorbar Example')
axs[1, 1].set_xlabel('Petal Length (cm)')
axs[1, 1].set_ylabel('Petal Width (cm)')

plt.tight_layout()
plt.show()
