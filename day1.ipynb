# %% [markdown]
#  All-in-One Guide to Use Jupyter Notebook in Visual Studio Code (VS Code)
#
# This guide helps you set up Jupyter Notebooks in VS Code with Python, virtual environments, and commonly used data science libraries — all in one place.
#
# ---
#
#  ✅ Prerequisites
#
# - Python (version 3.8 or above) → [Download Python](https://www.python.org/downloads/)
# - Visual Studio Code → [Download VS Code](https://code.visualstudio.com/)
#
# ---
#
#  🧩 Step 1: Install Python Extension in VS Code
#
# 1. Open **VS Code**
# 2. Go to the **Extensions** tab (or press `Ctrl+Shift+X`)
# 3. Search for **Python**
# 4. Click **Install** (published by Microsoft)
#
# ---
#
#  🧪 Step 2: Install Jupyter and IPython Kernel
#
# Open **Terminal** inside VS Code (`Ctrl + `` `) and run:
#
# ```bash
# pip install notebook jupyterlab ipykernel
#
# python -m venv myenv
#
# myenv\Scripts\activate  # On Windows
# myenv/bin\activate  # On Linux/Mac
#
# python -m ipykernel install --user --name=myenv --display-name "Python (myenv)"
#
# In VS Code, press Ctrl+Shift+P
#
# Type and select Jupyter: Create New Blank Notebook
#
# Or open an existing .ipynb file
#
# Choose your interpreter: Python (myenv)

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7,8]
y=[10,8,7,9,4,3,7,8]
plt.plot(x,y,marker="o")
plt.show()

# %% [markdown]
# The above example is not the correct form of visualisation. In visualisation legend and axis label are import and title for the plot also

# %%
x=[1,2,3,4,5,6,7,8]
y=[10,8,7,9,4,3,7,8]
plt.title("Sample plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.plot(x,y,marker="o")
plt.show()

# %%
x=[1,2,3,4,5,6,7,8]
y=[10,8,7,9,4,3,7,8]
plt.title("Sample plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.plot(x,y,marker="x",color='red')
plt.plot(x,y,linestyle="-.",color='black')
plt.legend(['data points'],loc='upper right')
plt.savefig('sampleplot.png')
plt.show()

# %% [markdown]
# This plot uses different colors for each point and a diamond marker to clearly distinguish values. Good for categorical representation.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [5, 8, 2, 6, 9]
colors = ['red', 'blue', 'green', 'orange', 'purple']

plt.scatter(x, y, c=colors, s=100, marker='D')  # Diamond markers with colors
plt.title('Scatter Plot with Colored Markers')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %% [markdown]
#  Bar chart with custom hex colors. Great for categorical data visualization.

# %%
x = ['A', 'B', 'C', 'D']
y = [3, 7, 5, 9]
colors = ['#FF5733', '#33FFBD', '#FF33EC', '#3385FF']

plt.bar(x, y, color=colors, width=0.5)
plt.title('Custom Colored Bar Chart')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# Adds a text label with an arrow pointing to a specific data point. Helpful for emphasizing key information.

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o', linestyle='-', color='green')
plt.title('Line Plot with Annotations')
plt.xlabel('X')
plt.ylabel('Y')

# Annotate a point
plt.annotate('Mid-point', xy=(3, 6), xytext=(3.5, 7),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.grid(True)
plt.show()

# %% [markdown]
# Compares two mathematical functions with different styles and a legend to distinguish them.

# %%
x = [0, 1, 2, 3, 4, 5]
y1 = [0, 1, 4, 9, 16, 25]
y2 = [0, 2, 8, 18, 32, 50]

plt.plot(x, y1, label='y = x²', color='blue', marker='s')
plt.plot(x, y2, label='y = 2x²', color='red', linestyle='--', marker='^')

plt.title('Comparing Two Functions')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()
plt.grid(True)
plt.show()
